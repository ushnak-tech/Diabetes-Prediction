# %% [markdown]
# # Dataset Description

# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("/content/diabetes.csv")

# %%
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  ...  DiabetesPedigreeFunction  Age  Outcome
# 0            6      148             72  ...                     0.627   50        1
# 1            1       85             66  ...                     0.351   31        0
# 2            8      183             64  ...                     0.672   32        1
# 3            1       89             66  ...                     0.167   21        0
# 4            0      137             40  ...                     2.288   33        1
#
# [5 rows x 9 columns]

# %% [markdown]
# # Number of Records:

# %%
print("No of records in the dataset:", len(data))
# Out:
# No of records in the dataset: 768

# %% [markdown]
# # Number of Attributes:

# %%
print("No of Attribues in the dataset:",len(data.columns))
# Out:
# No of Attribues in the dataset: 9

# %% [markdown]
# # Types of Attributes:

# %%
data.dtypes
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %% [markdown]
# #  Missing Values or Nulls:

# %%
data.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
data.isna().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  ...  DiabetesPedigreeFunction  Age  Outcome
# 0            6    148.0           72.0  ...                     0.627   50        1
# 1            1     85.0           66.0  ...                     0.351   31        0
# 2            8    183.0           64.0  ...                     0.672   32        1
# 3            1     89.0           66.0  ...                     0.167   21        0
# 4            0    137.0           40.0  ...                     2.288   33        1
#
# [5 rows x 9 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %% [markdown]
# # Distribution/Histograms:

# %%
fig, axes = plt.subplots(nrows = 3, ncols =3, figsize = (18, 14))
colors=["#428af5","#6c42f5","#42f566","#a742f5","#b9f542","#f5b042","#f57e42","#42f56c","#42f5e6"]
for index, column in enumerate(data.columns):
    ax = axes.flatten()[index]
    ax.hist(data[column], color = colors[index], label = column,alpha=0.8)
    ax.legend(loc = "best")
plt.suptitle("Distribution", size = 20)
plt.show()

# %%
import seaborn as sns

# %%
fig,ax=plt.subplots(2,2,figsize=(16,8))
sns.distplot(data['Glucose'],ax=ax[0,0])
sns.distplot(data['BMI'],ax=ax[0,1])
sns.distplot(data['BloodPressure'],ax=ax[1,0])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# #Detecting Outliers:

# %%
import seaborn as sns

# %%
data.plot(kind='box',layout=(5,2),subplots=True,figsize=(26,18),sharex=False,sharey=False)
# Out:
# Pregnancies                    AxesSubplot(0.125,0.749828;0.352273x0.130172)
# Glucose                     AxesSubplot(0.547727,0.749828;0.352273x0.130172)
# BloodPressure                  AxesSubplot(0.125,0.593621;0.352273x0.130172)
# SkinThickness               AxesSubplot(0.547727,0.593621;0.352273x0.130172)
# Insulin                        AxesSubplot(0.125,0.437414;0.352273x0.130172)
# BMI                         AxesSubplot(0.547727,0.437414;0.352273x0.130172)
# DiabetesPedigreeFunction       AxesSubplot(0.125,0.281207;0.352273x0.130172)
# Age                         AxesSubplot(0.547727,0.281207;0.352273x0.130172)
# Outcome                           AxesSubplot(0.125,0.125;0.352273x0.130172)
# dtype: object

# %%
data['Glucose'].plot(kind='box',figsize=(16,8))

# %%
import plotly.express as px

# %%
px.box(data_frame=data,x=['Glucose','SkinThickness','BloodPressure','BMI','Age'],color_discrete_sequence=['black'])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.box(data_frame=data,x='Insulin',color_discrete_sequence=['black'])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.box(data_frame=data,x='Pregnancies',color_discrete_sequence=['black'])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.box(data_frame=data,x='DiabetesPedigreeFunction',color_discrete_sequence=['black'])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Data Preprocessing:

# %% [markdown]
# #     HANDLING NULL VALUES:

# %%
data=data[data['BloodPressure']!=0]

# %%
data_column=['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI']
for i in data_column:
   data[i] = data[i].replace(0, np.NaN)     #replacing all zeroes to nan
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
data.isna().sum()
# Out:
# Pregnancies                   0
# Glucose                       5
# BloodPressure                 0
# SkinThickness               194
# Insulin                     339
# BMI                           4
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                       0
# dtype: int64

# %%
data['Glucose'].fillna(data['Glucose'].mean(),inplace=True)

# %%
data['SkinThickness'].mean(skipna=True)
# Out:
# 29.153419593345657

# %%
datax=data['SkinThickness']

# %%
datax=pd.DataFrame(datax,columns=['SkinThickness'])
datax
# Out:
#      SkinThickness
# 0             35.0
# 1             29.0
# 2              NaN
# 3             23.0
# 4             35.0
# ..             ...
# 763           48.0
# 764           27.0
# 765           23.0
# 766            NaN
# 767           31.0
#
# [768 rows x 1 columns]

# %%
filter=datax[datax['SkinThickness']==99.0]
datax=datax.drop(filter.index)
datax
# Out:
#      SkinThickness
# 0             35.0
# 1             29.0
# 2              NaN
# 3             23.0
# 4             35.0
# ..             ...
# 763           48.0
# 764           27.0
# 765           23.0
# 766            NaN
# 767           31.0
#
# [767 rows x 1 columns]

# %%
datax.mean()
# Out:
# SkinThickness    29.024074
# dtype: float64

# %%
data['SkinThickness'].fillna(data['SkinThickness'].mean(),inplace=True)

# %%
data['Insulin'].fillna(data['Insulin'].median(),inplace=True)

# %%
data['BMI'].fillna(data['BMI'].mean(),inplace=True)

# %%
data.isna().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
data.plot(kind='box',layout=(5,2),subplots=True,figsize=(26,18),sharex=False,sharey=False)

# %% [markdown]
# #  FEATURE SCALING:

# %% [markdown]
# #  Standardization

# %%
from sklearn.preprocessing import StandardScaler

# %%
data2=data.drop(columns=['Outcome'],axis=1)

# %%
data2

# %%
data.columns

# %%
data2.values
# Out:
# array([[  6.   , 148.   ,  72.   , ...,  33.6  ,   0.627,  50.   ],
#        [  1.   ,  85.   ,  66.   , ...,  26.6  ,   0.351,  31.   ],
#        [  8.   , 183.   ,  64.   , ...,  23.3  ,   0.672,  32.   ],
#        ...,
#        [  5.   , 121.   ,  72.   , ...,  26.2  ,   0.245,  30.   ],
#        [  1.   , 126.   ,  60.   , ...,  30.1  ,   0.349,  47.   ],
#        [  1.   ,  93.   ,  70.   , ...,  30.4  ,   0.315,  23.   ]])

# %%
sc=StandardScaler()

# %%
data2

# %%
data2=pd.DataFrame(data2,columns=['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
       'BMI', 'DiabetesPedigreeFunction', 'Age'])

# %%
data2
# Out:
# array([[ 0.63994726,  0.86510807, -0.03351824, ...,  0.46849198,
#          1.4259954 ,  1.36589591],
#        [-0.84488505, -1.20616153, -0.52985903, ..., -0.36506078,
#         -0.19067191, -0.73212021],
#        [ 1.23388019,  2.0158134 , -0.69530596, ...,  0.60439732,
#         -0.10558415,  1.36589591],
#        ...,
#        [ 0.3429808 , -0.0225789 , -0.03351824, ..., -0.68519336,
#         -0.27575966, -0.73212021],
#        [-0.84488505,  0.14180757, -1.02619983, ..., -0.37110101,
#          1.17073215,  1.36589591],
#        [-0.84488505, -0.94314317, -0.19896517, ..., -0.47378505,
#         -0.87137393, -0.73212021]])

# %%
data2.describe().round(2)
# Out:
#        Pregnancies  Glucose  ...  DiabetesPedigreeFunction     Age
# count       768.00   768.00  ...                    768.00  768.00
# mean          0.00    -0.00  ...                      0.00    0.00
# std           1.00     1.00  ...                      1.00    1.00
# min          -1.14    -2.55  ...                     -1.19   -1.04
# 25%          -0.84    -0.72  ...                     -0.69   -0.79
# 50%          -0.25    -0.15  ...                     -0.30   -0.36
# 75%           0.64     0.61  ...                      0.47    0.66
# max           3.91     2.54  ...                      5.88    4.06
#
# [8 rows x 8 columns]

# %%
data2['Outcome']=data['Outcome']
data2
# Out:
#      Pregnancies   Glucose  ...       Age  Outcome
# 0       0.639073  0.855106  ...  1.406583      1.0
# 1      -0.850878 -1.206859  ... -0.199639      0.0
# 2       1.235054  2.000642  ... -0.115101      1.0
# 3      -0.850878 -1.075941  ... -1.045019      0.0
# 4      -1.148868  0.495080  ... -0.030563      1.0
# ..           ...       ...  ...       ...      ...
# 728     1.831034 -0.683185  ...  2.505577      0.0
# 729    -0.552888  0.004136  ... -0.537791      0.0
# 730     0.341083 -0.028593  ... -0.284177      1.0
# 731    -0.850878  0.135055  ...  1.152969      1.0
# 732    -0.850878 -0.945022  ... -0.875943      1.0
#
# [733 rows x 9 columns]

# %% [markdown]
# #   Normalization

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
data2=data.drop(columns=['Outcome'],axis=1)

# %%
data2=data2.values

# %%
mmc=MinMaxScaler()
mmc.fit(data2)
data2=mmc.transform(data2)

# %%
data2=pd.DataFrame(data2,columns=['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
       'BMI', 'DiabetesPedigreeFunction', 'Age'])

# %%
data2['Outcome']=data['Outcome']
data2
# Out:
#      Pregnancies   Glucose  ...       Age  Outcome
# 0       0.352941  0.670968  ...  0.483333        1
# 1       0.058824  0.264516  ...  0.166667        0
# 2       0.470588  0.896774  ...  0.183333        1
# 3       0.058824  0.290323  ...  0.000000        0
# 4       0.000000  0.600000  ...  0.200000        1
# ..           ...       ...  ...       ...      ...
# 763     0.588235  0.367742  ...  0.700000        0
# 764     0.117647  0.503226  ...  0.100000        0
# 765     0.294118  0.496774  ...  0.150000        0
# 766     0.058824  0.529032  ...  0.433333        1
# 767     0.058824  0.316129  ...  0.033333        0
#
# [768 rows x 9 columns]

# %%
data2.describe().round(2)
# Out:
#        Pregnancies  Glucose  ...     Age  Outcome
# count       768.00   768.00  ...  768.00   768.00
# mean          0.23     0.50  ...    0.20     0.35
# std           0.20     0.20  ...    0.20     0.48
# min           0.00     0.00  ...    0.00     0.00
# 25%           0.06     0.36  ...    0.05     0.00
# 50%           0.18     0.47  ...    0.13     0.00
# 75%           0.35     0.62  ...    0.33     1.00
# max           1.00     1.00  ...    1.00     1.00
#
# [8 rows x 9 columns]

# %% [markdown]
# # feature selection and conversion

# %% [markdown]
# categorical to numerical

# %%
datax=data2.head(100)
datax
# Out:
#     Pregnancies   Glucose  ...       Age  Outcome
# 0      0.639947  0.865108  ...  1.425995        1
# 1     -0.844885 -1.206162  ... -0.190672        0
# 2      1.233880  2.015813  ... -0.105584        1
# 3     -0.844885 -1.074652  ... -1.041549        0
# 4     -1.141852  0.503458  ... -0.020496        1
# ..          ...       ...  ...       ...      ...
# 95     0.639947  0.733599  ...  0.575118        0
# 96    -0.547919 -0.976020  ... -0.786286        0
# 97    -0.844885 -1.666444  ... -0.956462        0
# 98     0.639947 -0.943143  ... -0.871374        0
# 99    -0.844885  0.010298  ... -0.190672        1
#
# [100 rows x 9 columns]

# %%
datax['Outcome'].replace({0:"Non Diabetic",1:"Diabetic"},inplace=True)
datax
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py:6619: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)
#     Pregnancies   Glucose  ...       Age       Outcome
# 0      0.639947  0.865108  ...  1.425995      Diabetic
# 1     -0.844885 -1.206162  ... -0.190672  Non Diabetic
# 2      1.233880  2.015813  ... -0.105584      Diabetic
# 3     -0.844885 -1.074652  ... -1.041549  Non Diabetic
# 4     -1.141852  0.503458  ... -0.020496      Diabetic
# ..          ...       ...  ...       ...           ...
# 95     0.639947  0.733599  ...  0.575118  Non Diabetic
# 96    -0.547919 -0.976020  ... -0.786286  Non Diabetic
# 97    -0.844885 -1.666444  ... -0.956462  Non Diabetic
# 98     0.639947 -0.943143  ... -0.871374  Non Diabetic
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
datax['Outcome']=le.fit_transform(datax['Outcome'])
datax.head(15)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#     Pregnancies   Glucose  ...       Age  Outcome
# 0      0.639947  0.865108  ...  1.425995        0
# 1     -0.844885 -1.206162  ... -0.190672        1
# 2      1.233880  2.015813  ... -0.105584        0
# 3     -0.844885 -1.074652  ... -1.041549        1
# 4     -1.141852  0.503458  ... -0.020496        0
# 5      0.342981 -0.186965  ... -0.275760        1
# 6     -0.250952 -1.436303  ... -0.616111        0
# 7      1.827813 -0.219843  ... -0.360847        1
# 8     -0.547919  2.476096  ...  1.681259        0
# ...

# %%
datax.tail()
# Out:
#     Pregnancies   Glucose  ...       Age  Outcome
# 95     0.639947  0.733599  ...  0.575118        1
# 96    -0.547919 -0.976020  ... -0.786286        1
# 97    -0.844885 -1.666444  ... -0.956462        1
# 98     0.639947 -0.943143  ... -0.871374        1
# 99    -0.844885  0.010298  ... -0.190672        0
#
# [5 rows x 9 columns]

# %% [markdown]
# #Feature Selection

# %% [markdown]
# # Train-Test Split:

# %%
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6    148.0             72      35.000000    125.0  33.6
# 1            1     85.0             66      29.000000    125.0  26.6
# 2            8    183.0             64      29.163265    125.0  23.3
# 3            1     89.0             66      23.000000     94.0  28.1
# 4            0    137.0             40      35.000000    168.0  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
X=data.iloc[:,:-1].values
y=data.iloc[:,-1].values

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=1)

# %%
X_test.shape
# Out:
# (147, 8)

# %%
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)

# %%
X_train
# Out:
# array([[ 0.98401762, -1.24414159,  0.49537126, ..., -0.46691026,
#          0.84275317,  0.25143266],
#        [-0.52787102, -0.73167265, -0.15842955, ..., -1.75797235,
#         -0.71307734, -0.51953004],
#        [ 2.79828398,  0.99791005,  1.31262227, ...,  1.17230342,
#          2.03302199,  0.50842022],
#        ...,
#        [ 0.98401762, -1.91675708,  0.49537126, ...,  0.01179816,
#         -0.25685636,  0.67974527],
#        [-0.52787102,  0.77370488,  0.33192106, ...,  0.82415184,
#         -0.43817495, -0.34820499],
#        [ 0.07688444, -0.34732094,  0.00502065, ...,  0.66458237,
#          2.66471257,  1.96468309]])

# %%
X_test
# Out:
# array([[ 2.19352853,  0.51747041,  0.16847086, ...,  0.51951921,
#          0.22860955,  1.45070796],
#        [ 2.79828398, -0.50746748, -0.15842955, ...,  0.24389921,
#         -0.66628544,  1.62203301],
#        [ 0.68163989, -0.5715261 ,  0.16847086, ..., -0.37987236,
#          0.71115096,  0.67974527],
#        ...,
#        [ 0.98401762, -0.50746748,  1.63952268, ..., -1.42432709,
#         -0.71307734,  1.27938292],
#        [ 1.8911508 ,  0.8377635 ,  0.98572187, ...,  0.73711394,
#          1.52708463,  1.53637049],
#        [ 2.79828398,  0.1331187 ,  1.47607247, ...,  1.57848025,
#          0.30464638,  0.76540779]])

# %% [markdown]
# # Building Models:
# # 1. K Nearest Neighbors

# %%
from sklearn.neighbors import KNeighborsClassifier
model1= KNeighborsClassifier(n_neighbors=5)
model1.fit(X_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred=model1.predict(X_test)

# %%
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_pred,y_test)
# Out:
# 0.7551020408163265

# %% [markdown]
# manipulating the value of k to see if the accuracy of the model changes

# %%
np.mean(y_pred!=y_test)
# Out:
# 0.24489795918367346

# %%
error_rate=[]
for i in range(1,28):
  classifier=KNeighborsClassifier(n_neighbors=i)
  classifier.fit(X_train,y_train)
  y_pred=classifier.predict(X_test)
  error_rate.append(np.mean(y_pred!=y_test))

plt.figure(figsize=(16,8))
plt.plot(range(1,28),error_rate,linestyle='dashed',marker='o',markerfacecolor='red')
plt.xlabel("Value of k")
plt.ylabel("Error rate")
# Out:
# Text(0, 0.5, 'Error rate')

# %%
print("Minimum error:-",min(error_rate),"at K =",error_rate.index(min(error_rate))+1)
# Out:
# Minimum error:- 0.19727891156462585 at K = 17

# %%
plt.rc('axes', titlesize=18)     # fontsize of the axes title
plt.rc('axes', labelsize=14)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=13)    # fontsize of the tick labels
plt.rc('ytick', labelsize=13)    # fontsize of the tick labels
plt.rc('legend', fontsize=13)    
plt.rc('font', size=13)

# %%
plt.style.context('fivethirtyeight')
acc = []
for i in range(1,40):
    neigh = KNeighborsClassifier(n_neighbors = i).fit(X_train,y_train)
    yhat = neigh.predict(X_test)
    acc.append(accuracy_score(y_test, yhat))
    
plt.figure(figsize=(10,6),tight_layout=True)
plt.plot(range(1,40),acc,color = 'blue',linestyle='dashed', 
         marker='o',markerfacecolor='black', markersize=10)
plt.title('accuracy vs. K Value')
plt.xlabel('K')
plt.ylabel('Accuracy')
plt.grid()

# %%
print("Maximum accuracy:-",max(acc),"at K =",acc.index(max(acc))+1
)
# Out:
# Maximum accuracy:- 0.8027210884353742 at K = 17

# %%
model1= KNeighborsClassifier(n_neighbors=17)
model1.fit(X_train,y_train)
y_pred=model1.predict(X_test)
accuracy_score(y_pred,y_test)
# Out:
# 0.8027210884353742

# %%
sns.color_palette('pastel')
# Out:
# [(0.6313725490196078, 0.788235294117647, 0.9568627450980393),
#  (1.0, 0.7058823529411765, 0.5098039215686274),
#  (0.5529411764705883, 0.8980392156862745, 0.6313725490196078),
#  (1.0, 0.6235294117647059, 0.6078431372549019),
#  (0.8156862745098039, 0.7333333333333333, 1.0),
#  (0.8705882352941177, 0.7333333333333333, 0.6078431372549019),
#  (0.9803921568627451, 0.6901960784313725, 0.8941176470588236),
#  (0.8117647058823529, 0.8117647058823529, 0.8117647058823529),
#  (1.0, 0.996078431372549, 0.6392156862745098),
#  (0.7254901960784313, 0.9490196078431372, 0.9411764705882353)]

# %%
sns.color_palette('Oranges')
# Out:
# [(0.9955709342560554, 0.8907958477508651, 0.7855132641291811),
#  (0.9921568627450981, 0.7769934640522875, 0.5727028066128412),
#  (0.9921568627450981, 0.6280507497116494, 0.34226835832372166),
#  (0.9648442906574395, 0.47100346020761247, 0.14197616301422528),
#  (0.8782929642445213, 0.31990772779700116, 0.024405997693194924),
#  (0.6768627450980392, 0.22089965397923875, 0.010749711649365626)]

# %%
sns.color_palette('Set3_r')
# Out:
# [(0.8, 0.9215686274509803, 0.7725490196078432),
#  (0.8509803921568627, 0.8509803921568627, 0.8509803921568627),
#  (0.7019607843137254, 0.8705882352941177, 0.4117647058823529),
#  (0.9921568627450981, 0.7058823529411765, 0.3843137254901961),
#  (0.984313725490196, 0.5019607843137255, 0.4470588235294118),
#  (1.0, 1.0, 0.7019607843137254)]

# %% [markdown]
# # Model2: Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
model2=GaussianNB()
model2.fit(X_train,y_train)
y_pred=model2.predict(X_test)
accuracy_score(y_pred,y_test)
# Out:
# 0.7891156462585034

# %%
model2.score(X_train,y_train)
# Out:
# 0.735494880546075

# %%
pd.DataFrame(y_test).value_counts()
# Out:
# 0    94
# 1    53
# dtype: int64

# %%
(94/(94+53)) # null accuracy score
# Out:
# 0.6394557823129252

# %% [markdown]
# # Model3: Decision tree classification algorithm

# %%
from sklearn.tree import DecisionTreeClassifier
model3=DecisionTreeClassifier(criterion='gini',max_depth=3,random_state=0) 
model3.fit(X_train,y_train) # with gini index as criterion
y_pred=model3.predict(X_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.7074829931972789

# %%
y_pred_train=model3.predict(X_train)
accuracy_score(y_pred_train,y_train)
# Out:
# 0.7747440273037542

# %%
model3.score(X_train,y_train)
# Out:
# 0.7747440273037542

# %%
from sklearn import tree

# %%
plt.figure(figsize=(25,12))
tree.plot_tree(model3.fit(X_train,y_train),filled=True)
plt.show()

# %% [markdown]
# # Information Gain as criterion

# %%
model3=DecisionTreeClassifier(criterion='entropy',max_depth=3,random_state=0) 
model3.fit(X_train,y_train) # with gini index as criterion
y_pred=model3.predict(X_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.7142857142857143

# %%
plt.figure(figsize=(25,12))
tree.plot_tree(model3.fit(X_train,y_train),filled=True)
plt.show()

# %%
print('Training set score: {:.4f}'.format(model3.score(X_train, y_train)))

print('Test set score: {:.4f}'.format(model3.score(X_test, y_test)))
# Out:
# Training set score: 0.7679
# Test set score: 0.7143

# %%
pip install dtreeviz

# %%
from dtreeviz.trees import dtreeviz # remember to load the package

plt.figure(figsize=(25,12))
viz = dtreeviz(model3, X, y,
                target_name="target",
                feature_names=data2.columns,
                class_names=list(data['Outcome']))

viz
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3208: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return asarray(a).size
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))

# %% [markdown]
# # Model Evaluation

# %%
pd.Series(y_test).value_counts()
# Out:
# 0    94
# 1    53
# dtype: int64

# %%
pd.Series(y_test).mean()   #this is the percentage of ones
# Out:
# 0.36054421768707484

# %%
1-pd.Series(y_test).mean()
# Out:
# 0.6394557823129252

# %% [markdown]
# 63% is our null accuracy meaning if the model predicts zero(non diabetic) everytime than for 63% our model will be predicting correct results

# %% [markdown]
# for knn our models accuracy is nearlyt 80%

# %%
pd.DataFrame(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1),columns=['y pred','y test']).tail(25)
# Out:
#      y pred  y test
# 122       0       0
# 123       0       0
# 124       0       0
# 125       0       0
# 126       1       1
# 127       1       1
# 128       0       0
# 129       0       0
# 130       0       0
# 131       0       0
# 132       0       0
# 133       0       1
# 134       0       0
# 135       1       1
# 136       0       1
# 137       0       1
# 138       0       0
# 139       1       1
# 140       1       1
# 141       0       0
# 142       0       0
# 143       0       0
# 144       0       0
# 145       1       1
# 146       0       1

# %% [markdown]
# here our model (maybe due to imabalanaced data) is making a certain type of errors whrere for 1s it is predicting 0 and for 0s it is predicting almost correct

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test,y_pred)
# Out:
# array([[87,  7],
#        [22, 31]])

# %% [markdown]
# the confusion matrix expects the first argument as the true values(original)

# %%
from sklearn.metrics import recall_score
recall=recall_score(y_test, y_pred)

# %%
recall
# Out:
# 0.5849056603773585

# %% [markdown]
# so that means for 58% of the times our model could predict the true cases and for rest nearly 40% of the true cases were predicted as false

# %% [markdown]
# SPECIFITY: when our actual value is negative so how well our model has predicted that negative value

# %%
Specifity=87/(87+7)   #specifity
Specifity
# Out:
# 0.925531914893617

# %% [markdown]
# that means for the 92% of the cases our model correctly predicted that the patients doesnt have diabetes

# %%
from sklearn.metrics import precision_score
precision=precision_score(y_test, y_pred)

# %% [markdown]
# that means for 81% of the time my model was able to correctly identify the true positives

# %%
31/(31+7)
# Out:
# 0.8157894736842105

# %% [markdown]
# adjusting the classification threshold

# %%
y_pred_prob=model1.predict_proba(X_test)
y_pred_prob[1:10,:]
# Out:
# array([[0.70588235, 0.29411765],
#        [0.52941176, 0.47058824],
#        [0.88235294, 0.11764706],
#        [0.35294118, 0.64705882],
#        [0.58823529, 0.41176471],
#        [0.47058824, 0.52941176],
#        [0.82352941, 0.17647059],
#        [0.76470588, 0.23529412],
#        [0.70588235, 0.29411765]])

# %%
y_pred_prob=y_pred_prob[:,1]

# %%
y_pred[1:10]
# Out:
# array([0, 0, 0, 1, 0, 1, 0, 0, 0])

# %%
plt.hist(y_pred_prob[:,1])
plt.xlim([0,1])
# Out:
# (0.0, 1.0)

# %%
y_pred_prob.shape
# Out:
# (147,)

# %%
from sklearn.preprocessing import binarize
y_pred_class=binarize(y_pred_prob,threshold=0.3)
y_pred_class

# %%
y_pred_prob[1:10,1]
# Out:
# array([0.29411765, 0.47058824, 0.11764706, 0.64705882, 0.41176471,
#        0.52941176, 0.17647059, 0.23529412, 0.29411765])

# %%
y_pred_class[1:10,1]
# Out:
# array([0., 1., 0., 1., 1., 1., 0., 0., 0.])

# %% [markdown]
# # Confusion matrix

# %%
cf_matrix=confusion_matrix(y_test,y_pred)

# %%
cf_matrix
# Out:
# array([[87,  7],
#        [22, 31]])

# %%
plt.rcParams['figure.figsize']=(12,6)
plt.rcParams['font.size']=15
import seaborn as sns
sns.heatmap(cf_matrix, annot=True)
plt.show()

# %%
sns.heatmap(cf_matrix/np.sum(cf_matrix), annot=True, 
            fmt='.2%', cmap='copper_r')
plt.show()

# %%
from sklearn.metrics import f1_score
f1=f1_score(y_test, y_pred)

# %%
df=pd.DataFrame([f1,recall,precision]).T
df.columns=['F1 Score','Recall','Precision']

# %%
df
# Out:
#    F1 Score    Recall  Precision
# 0  0.681319  0.584906   0.815789

# %% [markdown]
# # Model Evaluation for naive bayes:

# %%
sns.heatmap(cf_matrix/np.sum(cf_matrix), annot=True, 
            fmt='.2%', cmap='Blu')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-76-f12fb816f676> in <module>()
#       1 sns.heatmap(cf_matrix/np.sum(cf_matrix), annot=True,
# ----> 2             fmt='.2%', cmap='Blu')
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/lib/python3.7/dist-packages/seaborn/matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     540     plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     541                           annot_kws, cbar, cbar_kws, xticklabels,
# ...

# %%
cf_matrix=confusion_matrix(y_test,y_pred)
cf_matrix
# Out:
# array([[82, 12],
#        [19, 34]])

# %%
sns.heatmap(cf_matrix, annot=True,cmap='Oranges')
plt.show()

# %%
sns.heatmap(cf_matrix/np.sum(cf_matrix), annot=True, 
            fmt='.2%', cmap='copper_r')
plt.show()

# %%
recall=recall_score(y_test, y_pred)

# %%
from sklearn.metrics import precision_score
precision=precision_score(y_test, y_pred)
precision
# Out:
# 0.7391304347826086

# %%
recall
# Out:
# 0.6415094339622641

# %%
f1=f1_score(y_test, y_pred)
f1
# Out:
# 0.6868686868686867

# %%
cf_matrix=confusion_matrix(y_test,y_pred)
cf_matrix
# Out:
# array([[89,  5],
#        [37, 16]])

# %%
sns.heatmap(cf_matrix, annot=True,cmap='Oranges')
plt.show()

# %%
sns.heatmap(cf_matrix/np.sum(cf_matrix), annot=True, 
            fmt='.2%', cmap='copper_r')
plt.show()

# %%
precision=precision_score(y_test, y_pred)
precision
# Out:
# 0.7619047619047619

# %%
recall=recall_score(y_test, y_pred)
recall
# Out:
# 0.3018867924528302

# %%
f1=f1_score(y_test, y_pred)
f1
# Out:
# 0.43243243243243246
